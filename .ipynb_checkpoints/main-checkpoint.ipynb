# %% [markdown]
# # Main Program

# %%
import random
name = input("Enter your name: ")
panzerabwehrlenkflügkopgher = input("Give a word you LOVE: ")
reciprocated = random.randint(0, 1)
if reciprocated == 1:
    r_string = " LOVES"
else:
    r_string = " DOES NOT LOVE"
print("HOLY COW " + name + " DID YOU HEAR THAT " + panzerabwehrlenkflügkopgher + r_string + " YOU BACK?!?!?!")
# Out:
# Enter your name:  asdf
# Give a word you LOVE:  adsf
# HOLY COW asdf DID YOU HEAR THAT adsf LOVES YOU BACK?!?!?!
