# %% [markdown]
# # Main Program

# %%
import random
name = input("Enter your name: ")
other_input = input("Give a word you LOVE: ")
reciprocated = random.randint(0, 1)
if reciprocated == 1:
    r_string = ""
else:
    r_string = "NOT"
# Out:
# Enter your name:  Luke
